# %%
image_url="http://www.sun.org/uploads/images/mainimage_Orion_Molecular_Cloud_Wide_Field.jpg"

# %%
import requests
image_binary = requests.get(image_url).content
with open("orion.jpg","wb") as f:
    f.write(image_binary)

# %%
from PIL import Image
orion_image = Image.open('orion.jpg')

# %%
orion_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=950x618 at 0x22EF83731D0>

# %%
from pilkit.processors import Thumbnail
processor = Thumbnail(width=300, height=300)

# %%
thumb_image = processor.process(orion_image)

# %%
thumb_image
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x22EF89E8E48>

# %%
thumb_image.save('thumb-300x300.png')

thumb_image.mode = 'RGB'
for quality in [100, 80, 60, 40, 20]:
    thumb_image.save('thumb-300x300-{}.jpg'.format(quality), quality=quality)
